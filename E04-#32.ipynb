# %% [markdown]
# ### 模拟银行服务完成程序代码。
#
# #### 目前，在以银行营业大厅为代表的窗口行业中大量使用排队（叫号）系统，该系统完全模拟了人群排队全过程，通过取票进队、排队等待、叫号服务等功能，代替了人们站队的辛苦。
#
# #### 排队叫号软件的具体操作流程为：
#
# <font color=brown size=4 face=雅黑>**顾客取服务序号**</font>
# #### 当顾客抵达服务大厅时，前往放置在入口处旁的取号机，并按一下其上的相应服务按钮，取号机会自动打印出一张服务单。单上显示服务号及该服务号前面正在等待服务的人数。
#
# <font color=brown size=4 face=雅黑>**服务员工呼叫顾客**</font>
# #### 服务员工只需按一下其柜台上呼叫器的相应按钮，则顾客的服务号就会按顺序的显示在显示屏上，并发出“叮咚”和相关语音信息，提示顾客前往该窗口办事。当一位顾客办事完毕后，柜台服务员工只需按呼叫器相应键，即可自动呼叫下一位顾客。
#
# #### 编写程序模拟上面的工作过程，主要要求如下：
#
# ####     程序运行后，当看到“请点击触摸屏获取号码：”的提示时，只要按回车键，即可显示“您的号码是：XXX，您前面有YYY位”的提示，其中XXX是所获得的服务号码，YYY是在XXX之前来到的正在等待服务的人数。
# ####     用多线程技术模拟服务窗口（可模拟多个），具有服务员呼叫顾客的行为，假设每个顾客服务的时间是10000ms，时间到后，显示“请XXX号到ZZZ号窗口！”的提示。其中ZZZ是即将为客户服务的窗口号。

# %%
import time, threading

class Queue:
    def __init__(self):
        self.items = []

    def isEmpty(self):
        return self.items == []

    def enqueue(self, item):
        self.items.insert(0,item)

    def dequeue(self):
        if self.items != []:
            return self.items.pop()
        else:
            return False

    def size(self):
        return len(self.items)

    def top(self):
        if self.items != []:
            return self.items[len(self.items)-1]
        else:
            return False

class Counter(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.waitQueue = Queue() ## 初始化等待的队伍
        self.lock = threading.Lock()

    def callIng(self):
        while True:
            ### 柜台一直叫号，要一直循环
            time.sleep(5)
            if not self.waitQueue.isEmpty():
                self.lock.acquire()
                print("请客户{},到{}窗口办理业务".format(self.waitQueue.top(), threading.current_thread().name))
                self.waitQueue.dequeue()
                self.lock.release()


class bankSystem:
    def __init__(self):
        self.serviceQueue = Queue()
        self.nowNum = 0
        # self.windows = k  # 银行柜台数目
        self.maxSize = 100

    def getNumber(self):
        if self.nowNum < self.maxSize:
            self.nowNum += 1
            return self.nowNum
        else:
            print("现在业务繁忙，请稍后再来")


if __name__ == "__main__":
    res = bankSystem()
    windowcount = 3
    serviceWindow = [None] * windowcount
    threadList = [None] * windowcount

    for i in range(windowcount):
        serviceWindow[i] = Counter()
        serviceWindow[i].waitQueue = res.serviceQueue
        threadList[i] = threading.Thread(name=(i + 1), target=serviceWindow[i].callIng, args=())
        threadList[i].start()
        # threadList[i].join()

    while True:
        input("请点击触摸屏获取号码：")
        # print()
        callNumber = res.getNumber()
        if res.serviceQueue != None:
            print("当前您的的号码为" + str(callNumber) + "，您前面还有" + str(res.serviceQueue.size()) + "个人")
            res.serviceQueue.enqueue(res.nowNum)
        else:
            print('您的号码是：%d，您前面有 0 位' % (callNumber))
# Out:
# 请点击触摸屏获取号码：
# 当前您的的号码为1，您前面还有0个人
# 请点击触摸屏获取号码：
# 当前您的的号码为2，您前面还有1个人
# 请点击触摸屏获取号码：
# 当前您的的号码为3，您前面还有2个人
# 请点击触摸屏获取号码：
# 当前您的的号码为4，您前面还有3个人
# 请点击触摸屏获取号码：
# 当前您的的号码为5，您前面还有4个人
# 请点击触摸屏获取号码：
# 当前您的的号码为6，您前面还有5个人
# 请点击触摸屏获取号码：
# 当前您的的号码为7，您前面还有6个人
# 请点击触摸屏获取号码：
# 当前您的的号码为8，您前面还有7个人
# 请点击触摸屏获取号码：
# 当前您的的号码为9，您前面还有8个人
# 请点击触摸屏获取号码：
# 当前您的的号码为10，您前面还有9个人
# 请点击触摸屏获取号码：
# 当前您的的号码为11，您前面还有10个人
# 请点击触摸屏获取号码：
# 当前您的的号码为12，您前面还有11个人
# 请点击触摸屏获取号码：
# 当前您的的号码为13，您前面还有12个人
# 请点击触摸屏获取号码：
# 当前您的的号码为14，您前面还有13个人
# 请客户1,到2窗口办理业务请客户1,到1窗口办理业务
# 请客户2,到3窗口办理业务
#
# 请点击触摸屏获取号码：
# 当前您的的号码为15，您前面还有11个人
# 请点击触摸屏获取号码：
# 当前您的的号码为16，您前面还有12个人
# 请点击触摸屏获取号码：
# 当前您的的号码为17，您前面还有13个人
# 请点击触摸屏获取号码：
# 当前您的的号码为18，您前面还有14个人
# 请点击触摸屏获取号码：
# 当前您的的号码为19，您前面还有15个人
# 请点击触摸屏获取号码：
# 当前您的的号码为20，您前面还有16个人
# 请点击触摸屏获取号码：
# 当前您的的号码为21，您前面还有17个人
# 请点击触摸屏获取号码：
# 当前您的的号码为22，您前面还有18个人
# 请点击触摸屏获取号码：
# 当前您的的号码为23，您前面还有19个人
# 请点击触摸屏获取号码：
# 当前您的的号码为24，您前面还有20个人
# 请点击触摸屏获取号码：
# 当前您的的号码为25，您前面还有21个人
# 请点击触摸屏获取号码：
# 当前您的的号码为26，您前面还有22个人
# 请点击触摸屏获取号码：
# 当前您的的号码为27，您前面还有23个人
# 请点击触摸屏获取号码：
# 当前您的的号码为28，您前面还有24个人
# 请点击触摸屏获取号码：
# 当前您的的号码为29，您前面还有25个人
# 请点击触摸屏获取号码：
# 当前您的的号码为30，您前面还有26个人
# 请点击触摸屏获取号码：
# 当前您的的号码为31，您前面还有27个人
# 请点击触摸屏获取号码：
# 当前您的的号码为32，您前面还有28个人
# 请点击触摸屏获取号码：
# 当前您的的号码为33，您前面还有29个人
# 请点击触摸屏获取号码：
# 当前您的的号码为34，您前面还有30个人
# 请点击触摸屏获取号码：
# 当前您的的号码为35，您前面还有31个人
# 请点击触摸屏获取号码：
# 当前您的的号码为36，您前面还有32个人
# 请点击触摸屏获取号码：
# 当前您的的号码为37，您前面还有33个人
# 请点击触摸屏获取号码：
# 当前您的的号码为38，您前面还有34个人
# 请点击触摸屏获取号码：
# 当前您的的号码为39，您前面还有35个人
# 请点击触摸屏获取号码：
# 当前您的的号码为40，您前面还有36个人
# 请点击触摸屏获取号码：
# 请客户4,到1窗口办理业务
# 请客户5,到2窗口办理业务请客户5,到3窗口办理业务
#
# 当前您的的号码为41，您前面还有34个人
# 请点击触摸屏获取号码：
# 当前您的的号码为42，您前面还有35个人
# 请点击触摸屏获取号码：
# 当前您的的号码为43，您前面还有36个人
# 请点击触摸屏获取号码：
# 当前您的的号码为44，您前面还有37个人
# 请点击触摸屏获取号码：
# 当前您的的号码为45，您前面还有38个人
# 请点击触摸屏获取号码：
# 当前您的的号码为46，您前面还有39个人
# 请点击触摸屏获取号码：
# 当前您的的号码为47，您前面还有40个人
# 请点击触摸屏获取号码：
# 当前您的的号码为48，您前面还有41个人
# 请客户7,到1窗口办理业务
# 请客户8,到2窗口办理业务
# 请客户9,到3窗口办理业务
# 请客户10,到1窗口办理业务
# 请客户11,到2窗口办理业务
# 请客户12,到3窗口办理业务
# 请客户13,到1窗口办理业务
# 请客户14,到2窗口办理业务
# 请客户15,到3窗口办理业务
# 请客户16,到1窗口办理业务
# 请客户17,到2窗口办理业务
# 请客户18,到3窗口办理业务
# 请客户19,到1窗口办理业务
# 请客户20,到2窗口办理业务
# 请客户21,到3窗口办理业务
# 请客户22,到1窗口办理业务
# 请客户23,到2窗口办理业务
# 请客户24,到3窗口办理业务
# 请客户25,到1窗口办理业务
# 请客户26,到2窗口办理业务
# 请客户27,到3窗口办理业务
# 请客户28,到1窗口办理业务
# 请客户29,到2窗口办理业务
# 请客户30,到3窗口办理业务
# 请客户31,到1窗口办理业务
# 请客户32,到2窗口办理业务
# 请客户33,到3窗口办理业务
# 请客户34,到1窗口办理业务
# 请客户35,到2窗口办理业务
# 请客户36,到3窗口办理业务
# 请客户37,到1窗口办理业务
# 请客户38,到3窗口办理业务请客户38,到2窗口办理业务
#
# 请客户40,到1窗口办理业务
# 请客户41,到2窗口办理业务
# 请客户42,到3窗口办理业务
# 请客户43,到1窗口办理业务
# 请客户44,到2窗口办理业务
# 请客户45,到3窗口办理业务
# 请客户46,到1窗口办理业务
# 请客户47,到2窗口办理业务
# 请客户48,到3窗口办理业务

# %%
import time, threading

class Queue:
    def __init__(self):
        self.items = []

    def isEmpty(self):
        return self.items == []

    def enqueue(self, item):
        self.items.insert(0,item)

    def dequeue(self):
        if self.items != []:
            return self.items.pop()
        else:
            return False

    def size(self):
        return len(self.items)

    def top(self):
        if self.items != []:
            return self.items[len(self.items)-1]
        else:
            return False

class Counter(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.waitQueue = Queue() ## 初始化等待的队伍
        self.lock = threading.Lock()

    def callIng(self):
        while True:
            ### 柜台一直叫号，要一直循环
            if not self.waitQueue.isEmpty():
                flag=self.lock.acquire()
                if not(flag):
                    print(flag)
                print("请客户{},到{}窗口办理业务".format(self.waitQueue.top(), threading.current_thread().name))
                self.waitQueue.dequeue()
                self.lock.release()
                time.sleep(5)

class bankSystem:
    def __init__(self):
        self.serviceQueue = Queue()
        self.nowNum = 0
        # self.windows = k  # 银行柜台数目
        self.maxSize = 100

    def getNumber(self):
        if self.nowNum < self.maxSize:
            self.nowNum += 1
            return self.nowNum
        else:
            print("现在业务繁忙，请稍后再来")


if __name__ == "__main__":
    res = bankSystem()
    windowcount = 3
    serviceWindow = [None] * windowcount
    threadList = [None] * windowcount

    for i in range(windowcount):
        serviceWindow[i] = Counter()
        serviceWindow[i].waitQueue = res.serviceQueue
        threadList[i] = threading.Thread(name=(i + 1), target=serviceWindow[i].callIng, args=())
        threadList[i].start()
        # threadList[i].join()

    while True:
        input("请点击触摸屏获取号码：")
        # print()
        callNumber = res.getNumber()
        if res.serviceQueue != None:
            print("当前您的的号码为" + str(callNumber) + "，您前面还有" + str(res.serviceQueue.size()) + "个人")
            res.serviceQueue.enqueue(res.nowNum)
        else:
            print('您的号码是：%d，您前面有 0 位' % (callNumber))
# Out:
# 请点击触摸屏获取号码：
# 当前您的的号码为1，您前面还有0个人
# 请客户1,到1窗口办理业务
# 请点击触摸屏获取号码：
# 当前您的的号码为2，您前面还有0个人
# 请客户2,到3窗口办理业务
# 请点击触摸屏获取号码：
# 当前您的的号码为3，您前面还有0个人
# 请客户3,到2窗口办理业务
# 请点击触摸屏获取号码：
# 当前您的的号码为4，您前面还有0个人
# 请点击触摸屏获取号码：
# 当前您的的号码为5，您前面还有1个人
# 请点击触摸屏获取号码：
# 当前您的的号码为6，您前面还有2个人
# 请点击触摸屏获取号码：
# 当前您的的号码为7，您前面还有3个人
# 请点击触摸屏获取号码：
# 当前您的的号码为8，您前面还有4个人
# 请点击触摸屏获取号码：
# 当前您的的号码为9，您前面还有5个人
# 请点击触摸屏获取号码：
# 当前您的的号码为10，您前面还有6个人
# 请点击触摸屏获取号码：
# 当前您的的号码为11，您前面还有7个人
# 请点击触摸屏获取号码：
# 当前您的的号码为12，您前面还有8个人
# 请点击触摸屏获取号码：
# 当前您的的号码为13，您前面还有9个人
# 请点击触摸屏获取号码：
# 当前您的的号码为14，您前面还有10个人
# 请点击触摸屏获取号码：
# 当前您的的号码为15，您前面还有11个人
# 请点击触摸屏获取号码：
# 当前您的的号码为16，您前面还有12个人
# 请点击触摸屏获取号码：
# 当前您的的号码为17，您前面还有13个人
# 请点击触摸屏获取号码：
# 当前您的的号码为18，您前面还有14个人
# 请点击触摸屏获取号码：
# 当前您的的号码为19，您前面还有15个人
# 请点击触摸屏获取号码：
# 当前您的的号码为20，您前面还有16个人
# 请点击触摸屏获取号码：
# 当前您的的号码为21，您前面还有17个人
# 请客户4,到1窗口办理业务
# 请点击触摸屏获取号码：
# 当前您的的号码为22，您前面还有17个人
# 请点击触摸屏获取号码：
# 当前您的的号码为23，您前面还有18个人
# 请点击触摸屏获取号码：
# 请客户5,到3窗口办理业务
# 当前您的的号码为24，您前面还有18个人
# 请客户6,到2窗口办理业务
# 请点击触摸屏获取号码：
# 当前您的的号码为25，您前面还有18个人
# 请点击触摸屏获取号码：
# 当前您的的号码为26，您前面还有19个人
# 请点击触摸屏获取号码：
# 当前您的的号码为27，您前面还有20个人
# 请点击触摸屏获取号码：
# 当前您的的号码为28，您前面还有21个人
# 请点击触摸屏获取号码：
# 当前您的的号码为29，您前面还有22个人
# 请点击触摸屏获取号码：
# 当前您的的号码为30，您前面还有23个人
# 请点击触摸屏获取号码：
# 当前您的的号码为31，您前面还有24个人
# 请点击触摸屏获取号码：
# 当前您的的号码为32，您前面还有25个人
# 请点击触摸屏获取号码：
# 当前您的的号码为33，您前面还有26个人
# 请点击触摸屏获取号码：
# 当前您的的号码为34，您前面还有27个人
# 请点击触摸屏获取号码：
# 当前您的的号码为35，您前面还有28个人
# 请点击触摸屏获取号码：
# 当前您的的号码为36，您前面还有29个人
# 请点击触摸屏获取号码：
# 当前您的的号码为37，您前面还有30个人
# 请点击触摸屏获取号码：
# 当前您的的号码为38，您前面还有31个人
# 请点击触摸屏获取号码：
# 当前您的的号码为39，您前面还有32个人
# 请点击触摸屏获取号码：
# 当前您的的号码为40，您前面还有33个人
# 请客户7,到1窗口办理业务
# 请点击触摸屏获取号码：
# 当前您的的号码为41，您前面还有33个人
# 请客户8,到3窗口办理业务
# 请点击触摸屏获取号码：
# 当前您的的号码为42，您前面还有33个人
# 请点击触摸屏获取号码：
# 当前您的的号码为43，您前面还有34个人
# 请点击触摸屏获取号码：
# 请客户9,到2窗口办理业务
# 当前您的的号码为44，您前面还有34个人
# 请点击触摸屏获取号码：
# 当前您的的号码为45，您前面还有35个人
# 请点击触摸屏获取号码：
# 当前您的的号码为46，您前面还有36个人
# 请点击触摸屏获取号码：
# 当前您的的号码为47，您前面还有37个人
# 请点击触摸屏获取号码：
# 当前您的的号码为48，您前面还有38个人
# 请点击触摸屏获取号码：
# 当前您的的号码为49，您前面还有39个人
# 请点击触摸屏获取号码：
# 当前您的的号码为50，您前面还有40个人
# 请点击触摸屏获取号码：
# 当前您的的号码为51，您前面还有41个人
# 请点击触摸屏获取号码：
# 当前您的的号码为52，您前面还有42个人
